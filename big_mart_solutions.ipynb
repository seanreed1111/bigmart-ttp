# %%
import numpy as np
import pandas as pd
pd.options.display.max_rows = 999

df = pd.read_csv('big_mart.csv')

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# #### Create a groupby object using Outlet Location Type

# %%
a = df.groupby('Outlet_Location_Type')

# %%
df.groupby('Outlet_Type').sum()
b = df.groupby('Outlet_Type')
b.aggregate(np.sum)
df.groupby('Outlet_Type').agg(np.mean)
# Out:
#                    Item_Weight  Item_Visibility    Item_MRP  \
# Outlet_Type
# Grocery Store        12.913153         0.104862  140.294688
# Supermarket Type1    12.849509         0.060723  141.213894
# Supermarket Type2    12.873346         0.061014  141.678634
# Supermarket Type3          NaN         0.058615  139.801791
#
#                    Outlet_Establishment_Year  Item_Outlet_Sales
# Outlet_Type
# Grocery Store                    1991.662050         339.828500
# Supermarket Type1                1999.322933        2316.181148
# Supermarket Type2                2009.000000        1995.498739
# Supermarket Type3                1985.000000        3694.038558

# %%
b.aggregate(np.sum)
# Out:
#                    Item_Weight  Item_Visibility     Item_MRP  \
# Outlet_Type
# Grocery Store         7166.800       113.565873  151939.1470
# Supermarket Type1    71661.710       338.651189  787549.8868
# Supermarket Type2    11946.465        56.621454  131477.7724
# Supermarket Type3        0.000        54.804764  130714.6746
#
#                    Outlet_Establishment_Year  Item_Outlet_Sales
# Outlet_Type
# Grocery Store                        2156970       3.680343e+05
# Supermarket Type1                   11150224       1.291734e+07
# Supermarket Type2                    1864352       1.851823e+06
# Supermarket Type3                    1855975       3.453926e+06

# %%
a.aggregate(np.sum)
df.groupby('Outlet_Location_Type').aggregate(np.sum)
# Out:
#                       Item_Weight  Item_Visibility     Item_MRP  \
# Outlet_Location_Type
# Tier 1                  23979.350       170.038072  336397.8120
# Tier 2                  35560.630       169.990299  393150.6416
# Tier 3                  31234.995       223.614910  472133.0272
#
#                       Outlet_Establishment_Year  Item_Outlet_Sales
# Outlet_Location_Type
# Tier 1                                  4764360       4.482059e+06
# Tier 2                                  5582060       6.472314e+06
# Tier 3                                  6681101       7.636753e+06

# %%
df.Item_Type
# Out:
# 0                       Dairy
# 1                 Soft Drinks
# 2                        Meat
# 3       Fruits and Vegetables
# 4                   Household
#                 ...
# 8518              Snack Foods
# 8519             Baking Goods
# 8520       Health and Hygiene
# 8521              Snack Foods
# 8522              Soft Drinks
# Name: Item_Type, Length: 8523, dtype: object

# %%
b.groups
# Out:
# {'Grocery Store': Int64Index([   3,   23,   28,   29,   30,   45,   49,   59,   63,   65,
#              ...
#              8442, 8449, 8454, 8458, 8469, 8473, 8480, 8486, 8490, 8509],
#             dtype='int64', length=1083),
#  'Supermarket Type1': Int64Index([   0,    2,    4,    6,    8,    9,   10,   11,   12,   13,
#              ...
#              8508, 8510, 8512, 8513, 8514, 8517, 8518, 8519, 8520, 8522],
#             dtype='int64', length=5577),
#  'Supermarket Type2': Int64Index([   1,    5,   16,   31,   32,   37,   43,   55,   60,   82,
#              ...
#              8482, 8489, 8491, 8498, 8505, 8506, 8511, 8515, 8516, 8521],
#             dtype='int64', length=928),
#  'Supermarket Type3': Int64Index([   7,   18,   21,   36,   38,   39,   62,   64,   84,   87,
#              ...
#              8383, 8422, 8435, 8444, 8463, 8472, 8485, 8487, 8488, 8504],
#             dtype='int64', length=935)}

# %%
a = df.groupby(['Outlet_Location_Type'])

# %% [markdown]
# #### Find a count of the outlet location types using .count()  What does this resulting dataframe tell us about missing data?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
a.count()
# Out:
#                       Item_Identifier  Item_Weight  Item_Fat_Content  \
# Outlet_Location_Type
# Tier 1                           2388         1860              2388
# Tier 2                           2785         2785              2785
# Tier 3                           3350         2415              3350
#
#                       Item_Visibility  Item_Type  Item_MRP  Outlet_Identifier  \
# Outlet_Location_Type
# Tier 1                           2388       2388      2388               2388
# Tier 2                           2785       2785      2785               2785
# Tier 3                           3350       3350      3350               3350
#
#                       Outlet_Establishment_Year  Outlet_Size  Outlet_Type  \
# Outlet_Location_Type
# Tier 1                                     2388         2388         2388
# Tier 2                                     2785          930         2785
# Tier 3                                     3350         2795         3350
#
# ...

# %%
type(df.groupby('Outlet_Location_Type').aggregate(np.sum))

c['column_name']
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Show total sales (Item Outlet Sales) by Outlet Location Type, round your result to 2 decimals

# %%
df.groupby('Outlet_Location_Type').sum().round(2)[['Item_Weight','Item_Outlet_Sales']]
# Out:
#                       Item_Weight  Item_Outlet_Sales
# Outlet_Location_Type
# Tier 1                   23979.35         4482059.07
# Tier 2                   35560.63         6472313.71
# Tier 3                   31234.99         7636752.63

# %%
df.groupby('Outlet_Location_Type')[['Item_Weight','Item_Outlet_Sales']].sum().round(2)
# Out:
#                       Item_Weight  Item_Outlet_Sales
# Outlet_Location_Type
# Tier 1                   23979.35         4482059.07
# Tier 2                   35560.63         6472313.71
# Tier 3                   31234.99         7636752.63

# %%
df.groupby('Outlet_Location_Type')[['Item_Outlet_Sales']].sum().round(2)

# %%
a.sum()[['Item_Outlet_Sales']].round(2)

# %%
a.groups

# %% [markdown]
# #### Retrieve just the Tier 1 members from your groupby object, you can use the .get_group method and tell it which group you want

# %%
mask = df['Outlet_Location_Type']=='Tier 1'

# %%
df[mask]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 2              FDN15        17.50          Low Fat         0.016760
# 10             FDY07        11.80          Low Fat         0.000000
# 11             FDA03        18.50          Regular         0.045464
# 12             FDX32        15.10          Regular         0.100014
# ...              ...          ...              ...              ...
# 8480           FDQ58          NaN          Low Fat         0.000000
# 8490           FDU44          NaN          Regular         0.102296
# 8492           FDT34         9.30          Low Fat         0.174350
# 8517           FDF53        20.75              reg         0.083607
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
mask = df['Item_Type']=='Dairy'

df[mask]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0              FDA15        9.300          Low Fat         0.016047     Dairy
# 11             FDA03       18.500          Regular         0.045464     Dairy
# 19             FDU02       13.350          Low Fat         0.102492     Dairy
# 28             FDE51        5.925          Regular         0.161467     Dairy
# 30             FDV38       19.250          Low Fat         0.170349     Dairy
# 40             FDU02       13.350          Low Fat         0.102512     Dairy
# 45             FDM39        6.420               LF         0.089499     Dairy
# 49             FDS02          NaN          Regular         0.255395     Dairy
# 67             FDZ03       13.650          Regular         0.078946     Dairy
# 91             DRG27        8.895          Low Fat         0.105274     Dairy
# 110            FDD03       13.300          Low Fat         0.079806     Dairy
# ...

# %%
#a = df.groupby('Outlet_Location_Type')

# %%
df.groupby('Outlet_Location_Type').get_group('Tier 1')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 2              FDN15        17.50          Low Fat         0.016760
# 10             FDY07        11.80          Low Fat         0.000000
# 11             FDA03        18.50          Regular         0.045464
# 12             FDX32        15.10          Regular         0.100014
# ...              ...          ...              ...              ...
# 8480           FDQ58          NaN          Low Fat         0.000000
# 8490           FDU44          NaN          Regular         0.102296
# 8492           FDT34         9.30          Low Fat         0.174350
# 8517           FDF53        20.75              reg         0.083607
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# #### Find the mean and median of the Sales and Visibility metrics for each Outlet Location Type

# %%
df.groupby('Outlet_Location_Type').agg([np.mean, np.median])[['Item_Outlet_Sales', 'Item_Visibility']]
# Out:
#                      Item_Outlet_Sales            Item_Visibility
#                                   mean     median            mean    median
# Outlet_Location_Type
# Tier 1                     1876.909159  1487.3972        0.071205  0.056450
# Tier 2                     2323.990559  2004.0580        0.061038  0.051766
# Tier 3                     2279.627651  1812.3076        0.066751  0.053906

# %%
df.groupby('Outlet_Location_Type')[['Item_Outlet_Sales', 'Item_Visibility']].aggregate([np.mean,np.median])

# %% [markdown]
# #### Find average Item_MRP and average Item_Outlet_Sales by Outlet_Type and Item_Type

# %%
df.groupby(['Outlet_Type','Item_Type']).agg(np.mean)[['Item_MRP', 'Item_Outlet_Sales']]

# %%
df.groupby(['Outlet_Type','Item_Type']).agg(mean_MRP=('Item_MRP',np.mean),mean_Sales=('Item_Outlet_Sales',np.mean))

# %% [markdown]
# #### Let's look at total sales by Item_Type, sort descending so top selling products are listed first

# %%
df.groupby('Item_Type')['Item_Outlet_Sales'].agg(np.sum).round(2).sort_values(ascending=False)

# %%
df['Item_Outlet_Sales']

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### What if we wanted to know what % each row makes up of its items total sales?

# %%
df.groupby('Item_Type').agg(np.sum)[['Item_Outlet_Sales']].round(2)
# Out:
#                        Item_Outlet_Sales
# Item_Type
# Baking Goods                  1265525.34
# Breads                         553237.19
# Breakfast                      232298.95
# Canned                        1444151.49
# Dairy                         1522594.05
# Frozen Foods                  1825734.79
# Fruits and Vegetables         2820059.82
# Hard Drinks                    457793.43
# Health and Hygiene            1045200.14
# Household                     2055493.71
# Meat                           917565.61
# Others                         325517.61
# Seafood                        148868.22
# Snack Foods                   2732786.09
# Soft Drinks                    892897.72
# Starchy Foods                  351401.25

# %%
c.groups
# Out:
# {'Baking Goods': Int64Index([   5,   21,   23,   48,   71,   77,   84,  106,  107,  156,
#              ...
#              8361, 8381, 8382, 8408, 8416, 8435, 8441, 8465, 8515, 8519],
#             dtype='int64', length=648),
#  'Breads': Int64Index([  33,  114,  124,  169,  175,  303,  327,  329,  350,  351,
#              ...
#              7998, 7999, 8065, 8151, 8191, 8198, 8240, 8334, 8370, 8413],
#             dtype='int64', length=251),
#  'Breakfast': Int64Index([  15,   17,   87,  157,  264,  291,  335,  339,  510,  567,
#              ...
#              7881, 7901, 7944, 7949, 8072, 8136, 8222, 8303, 8317, 8335],
#             dtype='int64', length=110),
#  'Canned': Int64Index([  29,   43,   44,   47,   52,   59,   73,   79,  105,  122,
#              ...
#              8403, 8406, 8412, 8420, 8437, 8438, 8449, 8455, 8489, 8514],
#             dtype='int64', length=649),
#  'Dairy': Int64Index([   0,   11,   19,   28,   30,   40,   45,   49,   67,   91,
#              ...
# ...

# %%
#Let's take our sum by group from above and using transform, we get a result for every row in our dataframe
#with it's corresponding sum of item sales
df.groupby('Item_Type')["Item_Outlet_Sales"].transform(lambda x: x.sum()).round(2)
# Out:
# 0       1522594.05
# 1        892897.72
# 2        917565.61
# 3       2820059.82
# 4       2055493.71
#            ...
# 8518    2732786.09
# 8519    1265525.34
# 8520    1045200.14
# 8521    2732786.09
# 8522     892897.72
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
#We can make a new column out of this

# %%
#df['total_item_sales'] = 
df['Item_Outlet_Sales'] = df.groupby('Item_Type')["Item_Outlet_Sales"].transform(lambda x: x.sum()).round(2)
# Out:
# 0       1522594.05
# 1        892897.72
# 2        917565.61
# 3       2820059.82
# 4       2055493.71
#            ...
# 8518    2732786.09
# 8519    1265525.34
# 8520    1045200.14
# 8521    2732786.09
# 8522     892897.72
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
#df.drop('%_total_item_sales', axis=1, inplace=True)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df['%_total_item_sale'] = df['Item_Outlet_Sales'] / df['total_item_sales']

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# #### Let's fill the NAs in the 'Item Weight' column. Group by Item_Fat_Content, and Item_Type and find the average weight for those groupings. Each item with a missing weight should be assigned the average weight of the group it belongs to.

# %%
df[df['Item_Weight'].isna()]

# %%
df.groupby(['Item_Fat_Content','Item_Type'])['Item_Weight'].transform(lambda x: x.fillna(x.mean()))

# %%
df.groupby('Item_Type').agg(np.sum).round(2)

# %%
df.groupby(['Item_Fat_Content','Item_Type'])[['Item_Weight']].agg(np.mean)
#df.groupby(['Item_Fat_Content','Item_Type'])['Item_Weight'].groups

# %%
df[df['Item_Weight'].isna()]

# %%
df['Item_Weight'] = df.groupby(['Item_Fat_Content','Item_Type'])['Item_Weight'].transform(lambda x: x.fillna(x.mean()))

# %%
df.iloc[[7]]

# %% [markdown]
# #### Using the same Item_Fat_Content and Item_type grouping, filter out any rows where the average item weight for those groups is less than 12

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.groupby(['Item_Fat_Content','Item_Type']).filter(lambda x: x.Item_Weight.mean()<12)

# %%
df2 = df.groupby(['Item_Fat_Content','Item_Type']).filter(lambda x : x.Item_Weight.mean() < 12 )

# %%
z = df2['Item_Fat_Content']=='LF'
y = df2['Item_Type']=='Fruits and Vegetables'

df2[z & y]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1021           FDI45       13.100               LF         0.037550
# 1051           FDW08          NaN               LF         0.147663
# 1278           FDN44       13.150               LF         0.022925
# 1551           FDX43        5.655               LF         0.085275
# 1978           FDC20       10.650               LF         0.023971
# 2048           FDT20       10.500               LF         0.041388
# 2188           FDD20       14.150               LF         0.020799
# 2279           FDD20       14.150               LF         0.020715
# 2308           FDP56        8.185               LF         0.046556
# 2709           FDA44       19.700               LF         0.053440
# 2784           FDP19       11.500               LF         0.173483
# 2834           FDA31        7.100               LF         0.110460
# 2948           FDU08          NaN               LF         0.027183
# ...

# %%
df['Item_Weight'] <12
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 8518     True
# 8519     True
# 8520     True
# 8521     True
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
df.groupby(['Item_Fat_Content', 'Item_Type']).agg(np.mean)['Item_Weight']
# Out:
# Item_Fat_Content  Item_Type
# LF                Baking Goods             12.052500
#                   Breads                   12.420000
#                   Breakfast                13.747500
#                   Canned                   13.201250
#                   Dairy                    13.281522
#                   Frozen Foods             13.018947
#                   Fruits and Vegetables    11.892581
#                   Hard Drinks              11.345714
#                   Health and Hygiene       13.323000
#                   Household                12.699111
#                   Meat                     13.210714
#                   Others                   15.348889
#                   Seafood                  11.941250
#                   Snack Foods              13.875000
#                   Soft Drinks              10.969091
#                   Starchy Foods            14.375000
# Low Fat           Baking Goods             12.633128
# ...

# %%
df.groupby(['Item_Fat_Content', 'Item_Type']).groups
# Out:
# {('LF',
#   'Baking Goods'): Int64Index([ 621,  805, 1179, 1403, 1653, 1865, 1869, 2321, 2815, 3140, 3474,
#              3573, 5212, 5264, 6142, 6252, 7139, 7416, 8128, 8157],
#             dtype='int64'),
#  ('LF',
#   'Breads'): Int64Index([175, 946, 4555, 5506, 5536, 5552, 6045, 6442], dtype='int64'),
#  ('LF', 'Breakfast'): Int64Index([4758, 5198], dtype='int64'),
#  ('LF',
#   'Canned'): Int64Index([ 551, 1335, 1955, 2028, 2207, 2347, 3059, 3823, 3830, 4258, 4325,
#              5248, 6011, 6453, 7640, 7769, 8273],
#             dtype='int64'),
#  ('LF',
#   'Dairy'): Int64Index([  45,  415,  851, 1286, 1589, 1655, 2244, 2697, 4093, 4101, 4206,
#              4238, 4782, 4978, 5229, 5505, 5590, 5868, 6172, 7051, 7212, 7307,
#              7543, 8103],
#             dtype='int64'),
#  ('LF',
#   'Frozen Foods'): Int64Index([ 504,  905, 1305, 1802, 2043, 2456, 2601, 2755, 3073, 3361, 3403,
#              3893, 4008, 4508, 4630, 5709, 6704, 7008, 7203, 7404, 7593, 7729],
# ...
